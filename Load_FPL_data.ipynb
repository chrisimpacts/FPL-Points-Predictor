# %%
teams_by_season = {
    20162017: {
        1: "Arsenal",
        2: "Bournemouth",
        3: "Burnley",
        4: "Chelsea",
        5: "Crystal Palace",
        6: "Everton",
        7: "Hull",
        8: "Leicester",
        9: "Liverpool",
        10: "Man City",
        11: "Man Utd",
        12: "Middlesbrough",
        13: "Southampton",
        14: "Stoke",
        15: "Sunderland",
        16: "Swansea",
        17: "Spurs",
        18: "Watford",
        19: "West Brom",
        20: "West Ham",
    },
    20172018: {
        1: "Arsenal",
        2: "Bournemouth",
        3: "Brighton",
        4: "Burnley",
        5: "Chelsea",
        6: "Crystal Palace",
        7: "Everton",
        8: "Huddersfield",
        9: "Leicester",
        10: "Liverpool",
        11: "Man City",
        12: "Man Utd",
        13: "Newcastle",
        14: "Southampton",
        15: "Stoke",
        16: "Swansea",
        17: "Spurs",
        18: "Watford",
        19: "West Brom",
        20: "West Ham",
    },
    20182019: {
        1: "Arsenal",
        2: "Bournemouth",
        3: "Brighton",
        4: "Burnley",
        5: "Cardiff",
        6: "Chelsea",
        7: "Crystal Palace",
        8: "Everton",
        9: "Fulham",
        10: "Huddersfield",
        11: "Leicester",
        12: "Liverpool",
        13: "Man City",
        14: "Man Utd",
        15: "Newcastle",
        16: "Southampton",
        17: "Spurs",
        18: "Watford",
        19: "West Ham",
        20: "Wolves",
    },
    20192020: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Bournemouth",
        4: "Brighton",
        5: "Burnley",
        6: "Chelsea",
        7: "Crystal Palace",
        8: "Everton",
        9: "Leicester",
        10: "Liverpool",
        11: "Man City",
        12: "Man Utd",
        13: "Newcastle",
        14: "Norwich",
        15: "Sheffield Utd",
        16: "Southampton",
        17: "Spurs",
        18: "Watford",
        19: "West Ham",
        20: "Wolves",
    },
    20202021: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Brighton",
        4: "Burnley",
        5: "Chelsea",
        6: "Crystal Palace",
        7: "Everton",
        8: "Fulham",
        9: "Leicester",
        10: "Leeds",
        11: "Liverpool",
        12: "Man City",
        13: "Man Utd",
        14: "Newcastle",
        15: "Sheffield Utd",
        16: "Southampton",
        17: "Spurs",
        18: "West Brom",
        19: "West Ham",
        20: "Wolves",
    },
    20212022: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Brentford",
        4: "Brighton",
        5: "Burnley",
        6: "Chelsea",
        7: "Crystal Palace",
        8: "Everton",
        9: "Leicester",
        10: "Leeds",
        11: "Liverpool",
        12: "Man City",
        13: "Man Utd",
        14: "Newcastle",
        15: "Norwich",
        16: "Southampton",
        17: "Spurs",
        18: "Watford",
        19: "West Ham",
        20: "Wolves",
    },
    20222023: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Bournemouth",
        4: "Brentford",
        5: "Brighton",
        6: "Chelsea",
        7: "Crystal Palace",
        8: "Everton",
        9: "Fulham",
        10: "Leicester",
        11: "Leeds",
        12: "Liverpool",
        13: "Man City",
        14: "Man Utd",
        15: "Newcastle",
        16: "Nott'm Forest",
        17: "Southampton",
        18: "Spurs",
        19: "West Ham",
        20: "Wolves",
    },
    20232024: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Bournemouth",
        4: "Brentford",
        5: "Brighton",
        6: "Burnley",
        7: "Chelsea",
        8: "Crystal Palace",
        9: "Everton",
        10: "Fulham",
        11: "Liverpool",
        12: "Luton",
        13: "Man City",
        14: "Man Utd",
        15: "Newcastle",
        16: "Nott'm Forest",
        17: "Sheffield Utd",
        18: "Spurs",
        19: "West Ham",
        20: "Wolves",
    },
    20242025: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Bournemouth",
        4: "Brentford",
        5: "Brighton",
        6: "Chelsea",
        7: "Crystal Palace",
        8: "Everton",
        9: "Fulham",
        10: "Ipswich",
        11: "Leicester",
        12: "Liverpool",
        13: "Man City",
        14: "Man Utd",
        15: "Newcastle",
        16: "Nott'm Forest",
        17: "Southampton",
        18: "Spurs",
        19: "West Ham",
        20: "Wolves",
    },
    20252026: {
        1: "Arsenal",
        2: "Aston Villa",
        3: "Burnley",
        4: "Bournemouth",
        5: "Brentford",
        6: "Brighton",
        7: "Chelsea",
        8: "Crystal Palace",
        9: "Everton",
        10: "Fulham",
        11: "Leeds",
        12: "Liverpool",
        13: "Man City",
        14: "Man Utd",
        15: "Newcastle",
        16: "Nott'm Forest",
        17: "Sunderland",
        18: "Spurs",
        19: "West Ham",
        20: "Wolves",
    }
}

# %%
rename_gw_data_dict = {
            "name":"player_name_id",
            # "assists":"",
            # "attempted_passes":"",
            # "big_chances_created":"",
            # "big_chances_missed":"",
            # "bonus":"",
            # "bps":"",
            # "clean_sheets":"",
            "clearances_blocks_interceptions":"cbi",
            # "completed_passes":"",
            # "creativity":"",
            # "dribbles":"",
            # "ea_index":"",
            # "element":"",
            # "errors_leading_to_goal":"",
            # "errors_leading_to_goal_attempt":"",
            # "fixture":"",
            # "fouls":"",
            # "goals_conceded":"",
            # "goals_scored":"",
            # "ict_index":"",
            # "id":"",
            # "influence":"",
            # "key_passes":"",
            # "kickoff_time":"",
            # "kickoff_time_formatted":"",
            # "loaned_in":"",
            # "loaned_out":"",
            # "minutes":"",
            # "offside":"",
            # "open_play_crosses":"",
            # "opponent_team":"",
            # "own_goals":"",
            # "penalties_conceded":"",
            # "penalties_missed":"",
            # "penalties_saved":"",
            # "recoveries":"",
            # "red_cards":"",
            # "round":"",
            # "saves":"",
            # "selected":"",
            # "tackled":"",
            # "tackles":"",
            # "target_missed":"",
            # "team_a_score":"",
            # "team_h_score":"",
            # "threat":"",
            # "total_points":"",
            # "transfers_balance":"",
            # "transfers_in":"",
            # "transfers_out":"",
            # "value":"",
            # "was_home":"",
            # "winning_goals":"",
            # "yellow_cards":"",
            "GW":"gw",
        }

rename_fixture_data_dict = {
            "code":"fixture_code",
            # "deadline_time":"",
            # "deadline_time_formatted":"",
            # "event":"",
            # "event_day":"",
            # "finished":"",
            # "finished_provisional":"",
            "id":"fixture_id",
            "kickoff_time":"fixture_kickoff_time",
            "kickoff_time_formatted":"fixture_kickoff_time_formatted",
            "minutes":"fixture_minutes",
            # "provisional_start_time":"",
            "started":"fixture_started",
            "stats":"fixture_stats",
            # "team_a":"",
            # "team_a_difficulty":"",
            "team_a_score":"fixture_team_a_score",
            # "team_h":"",
            # "team_h_difficulty":"",
            "team_h_score":"fixture_team_h_score",
            "season":"fixture_season",
        }

# %%
import time
start=time.perf_counter()

# %%
import pandas as pd
import numpy as np
import re

class FPLDataLoader:
    # Class-level ELO ratings dictionary shared across all seasons
    _global_elo_ratings = {}
    
    def __init__(self, season: int, gw_url: str = None, gw_df = None, fixtures_path: str = None, fixtures_df = None, 
                 rename_gw_data_dict: dict = rename_gw_data_dict, rename_fixture_data_dict: dict = rename_fixture_data_dict, 
                 teams_by_season: dict = teams_by_season, reset_elo: bool = False):
        """
        Initialize the FPL data loader

        Args:
            season (int): The season (e.g. 20192020).
            gw_url (str): URL or path to the merged gameweek data CSV.
            gw_df (DataFrame): Alternative to gw_url - pass DataFrame directly.
            fixtures_path (str): Path to the fixtures CSV.
            fixtures_df (DataFrame): Alternative to fixtures_path.
            rename_gw_data_dict (dict): Dict that renames columns for clarity.
            rename_fixture_data_dict (dict): Dict that renames columns for clarity.
            teams_by_season (dict): Mapping of team IDs to names by season.
            reset_elo (bool): If True, reset all ELO ratings to start_rating.
        """
        self.season = season
        self.gw_url = gw_url
        self.gw_df = gw_df
        self.fixtures_path = fixtures_path
        self.fixtures_df = fixtures_df
        self.fpl_data = None
        self.fixtures = None
        self.merged_data = None
        self.teams_by_season = teams_by_season or {}
        self.rename_gw_data_dict = rename_gw_data_dict or {}
        self.rename_fixture_data_dict = rename_fixture_data_dict or {}
        self.K = 20  # ELO K-factor
        self.START_RATING = 1000
        
        if reset_elo:
            FPLDataLoader._global_elo_ratings = {}

    @classmethod
    #fixes the elo ratings to the class, so that the elo ratings persist for following seasons (as long as analysis is done sequentially)
    def get_global_elo_ratings(cls):
        """Get the current global ELO ratings dictionary."""
        return cls._global_elo_ratings.copy()

    def team_name(self, row, teams_by_season):
        if row['was_home']:
            return teams_by_season[row['fixture_season']].get(row['team_h'])
        else:
            return teams_by_season[row['fixture_season']].get(row['team_a'])
    
    def opp_team_name(self, row, teams_by_season):
        if row['was_home']:
            return teams_by_season[row['fixture_season']].get(row['team_a'])
        else:
            return teams_by_season[row['fixture_season']].get(row['team_h'])
    
    def away_team_name(self, row, teams_by_season):
        return teams_by_season[row['fixture_season']].get(row['team_a'])
    
    def home_team_name(self, row, teams_by_season):
        return teams_by_season[row['fixture_season']].get(row['team_h'])
    
    def format_player_name_id(text):
        result = re.sub(r'[^\w\s]', '', text).replace(' ', '_')
        return result

    def load_fpl_data(self):
        """Load the merged gameweek data from CSV or DataFrame and add a season column."""
        if self.gw_df is not None:
            self.fpl_data = self.gw_df.copy()
            self.fpl_data['gw'] = self.fpl_data['round']  
            #recreate player_name_id
            self.fpl_data['player_name_id'] = self.fpl_data.apply(lambda x: f"{x['first_name']} {x['second_name']}", axis=1)     
            #map position 1,2,3,4 to GK, DEF, MID, FWD
            position_map = {1: 'GK', 2: 'DEF', 3: 'MID', 4: 'FWD'}
            self.fpl_data['position'] = self.fpl_data['element_type'].map(position_map)
            #get team name
            columns_to_convert = ['expected_goals','expected_assists','expected_goal_involvements','expected_goals_conceded']
            self.fpl_data[columns_to_convert] = self.fpl_data[columns_to_convert].apply(pd.to_numeric, errors='coerce')


        elif self.gw_url:
            self.fpl_data = pd.read_csv(self.gw_url, encoding="latin1", engine="python")
        else:
            raise ValueError("Either gw_url or gw_df must be provided")
        
        self.fpl_data = self.fpl_data.rename(columns=self.rename_gw_data_dict)
        self.fpl_data["season"] = self.season
        return self.fpl_data

    def load_fixtures(self):
        """Load the fixtures CSV."""
        if self.fixtures_path:
            self.fixtures = pd.read_csv(self.fixtures_path, encoding="latin1", engine="python")
        elif self.fixtures_df is not None:
            self.fixtures = self.fixtures_df.copy()
        else:
            raise ValueError("Either fixtures_path or fixtures_df must be provided")

        self.fixtures = self.fixtures.rename(columns=self.rename_fixture_data_dict)
        self.fixtures['fixture_season'] = self.season
        self.fixtures['away_team_name'] = self.fixtures.apply(
            lambda row: self.away_team_name(row, self.teams_by_season), axis=1
        )
        self.fixtures['home_team_name'] = self.fixtures.apply(
            lambda row: self.home_team_name(row, self.teams_by_season), axis=1
        )

    def add_elo_to_fixtures(self):
        """Add ELO ratings to fixtures, carrying over from previous seasons."""
        # Sort by kickoff_time
        self.fixtures = self.fixtures.sort_values("fixture_kickoff_time").reset_index(drop=True)
        
        home_elo_list = []
        away_elo_list = []
        
        for _, row in self.fixtures.iterrows():
            home = row['home_team_name']
            away = row['away_team_name']
            
            # Get current ratings from global dictionary or default
            R_home = FPLDataLoader._global_elo_ratings.get(home, self.START_RATING)
            R_away = FPLDataLoader._global_elo_ratings.get(away, self.START_RATING)
            
            # Save pre-match ratings
            home_elo_list.append(R_home)
            away_elo_list.append(R_away)
            
            # Only update if scores are available
            if not np.isnan(row['fixture_team_h_score']) and not np.isnan(row['fixture_team_a_score']):
                home_score = row['fixture_team_h_score']
                away_score = row['fixture_team_a_score']
                
                # Actual results
                if home_score > away_score:
                    S_home, S_away = 1, 0
                elif home_score < away_score:
                    S_home, S_away = 0, 1
                else:
                    S_home, S_away = 0.5, 0.5
                
                # Expected results
                E_home = 1 / (1 + 10 ** ((R_away - R_home) / 400))
                E_away = 1 - E_home
                
                # Update ratings in global dictionary
                FPLDataLoader._global_elo_ratings[home] = R_home + self.K * (S_home - E_home)
                FPLDataLoader._global_elo_ratings[away] = R_away + self.K * (S_away - E_away)
        
        # Add to dataframe
        self.fixtures['home_team_elo'] = home_elo_list
        self.fixtures['away_team_elo'] = away_elo_list
        
        return self.fixtures

    def merge_data(self):
        """Merge FPL data with fixtures on fixture ID."""
        if self.fpl_data is None:
            self.load_fpl_data()
        if self.fixtures is None:
            self.load_fixtures()
            self.add_elo_to_fixtures()

        self.merged_data = self.fpl_data.merge(
            self.fixtures,
            left_on="fixture",
            right_on="fixture_id",
            suffixes=("", "_fixture"),
            how='left',
            validate='many_to_one'
        )
        
        self.merged_data['team_name'] = self.merged_data.apply(
            lambda row: self.team_name(row, self.teams_by_season), axis=1
        )
        self.merged_data['team_elo'] = self.merged_data.apply(
            lambda row: row["home_team_elo"] if row["was_home"] else row["away_team_elo"], 
            axis=1
        )
        self.merged_data['opp_team_name'] = self.merged_data.apply(
            lambda row: self.opp_team_name(row, self.teams_by_season), axis=1
        )
        self.merged_data['opp_team_elo'] = self.merged_data.apply(
            lambda row: row["away_team_elo"] if row["was_home"] else row["home_team_elo"], 
            axis=1
        )
        
        return self.merged_data

# %%
# 2018-19 Season
fpl_loader = FPLDataLoader(
    season=20182019,
    gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2018-19/gws/merged_gw.csv",
    fixtures_path=r"data\fixtures1819.csv"
)

fpl1819 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures1819 = fpl_loader.add_elo_to_fixtures()
merged1819 = fpl_loader.merge_data()

# %%
# 2019-20 Season
fpl_loader = FPLDataLoader(
    season=20192020,
    gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2019-20/gws/merged_gw.csv",
    fixtures_path=r"data\fixtures1920.csv"
)

fpl1920 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures1920 = fpl_loader.add_elo_to_fixtures()
merged1920 = fpl_loader.merge_data()

# %%
# 2020-21 Season
fpl_loader = FPLDataLoader(
    season=20202021,
    gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2020-21/gws/merged_gw.csv",
    fixtures_path=r"data\fixtures2021.csv"
)

fpl2021 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures2021 = fpl_loader.add_elo_to_fixtures()
merged2021 = fpl_loader.merge_data()

# %%
# 2021-22 Season
fpl_loader = FPLDataLoader(
    season=20212022,
    gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2021-22/gws/merged_gw.csv",
    fixtures_path=r"data\fixtures2122.csv"
)

fpl2122 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures2122 = fpl_loader.add_elo_to_fixtures()
merged2122 = fpl_loader.merge_data()

# %%
# 2022-23 Season
fpl_loader = FPLDataLoader(
    season=20222023,
    gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2022-23/gws/merged_gw.csv",
    fixtures_path=r"data\fixtures2223.csv"
)

fpl2223 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures2223 = fpl_loader.add_elo_to_fixtures()
merged2223 = fpl_loader.merge_data()

# %%
# 2023-24 Season
fpl_loader = FPLDataLoader(
    season=20232024,
    gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/gws/merged_gw.csv",
    fixtures_path=r"data\fixtures2324.csv"
)

fpl2324 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures2324 = fpl_loader.add_elo_to_fixtures()
merged2324 = fpl_loader.merge_data()

# %% [markdown]
# #Manual 24/25

# %%
gws1to21 = pd.read_csv(r"data\vaastavplayergwsmerged_gw1-21.csv", encoding='latin1')
gws22to38 = pd.read_csv(r"data\vaastavplayergwsmerged_gw22-38.csv", encoding='latin1')
fpl24_reworked = pd.concat([gws1to21,gws22to38],axis=0)
fpl24_reworked.to_csv("data/vaastav2425playergwsreworked.csv")

# 2024-25 Season
fpl_loader = FPLDataLoader(
    season=20242025,
    gw_url="data/vaastav2425playergwsreworked.csv",
    fixtures_path=r"data\fixtures2425.csv"
)

fpl2425 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures2425 = fpl_loader.add_elo_to_fixtures()
merged2425 = fpl_loader.merge_data()

# %% [markdown]
# # 25/26 from FPL API

# %%
# # 2025-26 Season

# import requests
# import pandas as pd
# url = "https://fantasy.premierleague.com/api/fixtures/"
# response = requests.get(url)
# response.raise_for_status()
# fix2526 = pd.DataFrame(response.json())

# ### Update fixtures here: https://github.com/vaastav/Fantasy-Premier-League/blob/master/data/2025-26/fixtures.csv
# fpl_loader = FPLDataLoader(
#     season=20252026,
#     gw_url="https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2025-26/gws/merged_gw.csv",
#     # fixtures_path=r"C:\Users\chris\Documents\Coding\python\Github Repos\FPL-Data-Analysis\data\fixtures2526gw9.csv"
#     fixtures_df=fix2526
# )

# fpl2526 = fpl_loader.load_fpl_data()
# fix_ = fpl_loader.load_fixtures()
# fixtures2526 = fpl_loader.add_elo_to_fixtures()
# merged2526 = fpl_loader.merge_data()

# #one fixture each for home & away
# home_fixtures2526 = fixtures2526.copy().rename(columns={
#     'team_a':'opp_team',
#     'fixture_team_a_score':'fixture_opp_team_score',
#     'team_h':'team',
#     'fixture_team_h_score':'fixture_team_score',
#     'team_h_difficulty':'team_difficulty',
#     'team_a_difficulty':'opp_team_difficulty',
#     'away_team_name':'opp_team_name',
#     'home_team_name':'team_name',
#     'home_team_elo':'team_elo',
#     'away_team_elo':'opp_team_elo',
#     'team':'team_code'})
# away_fixtures2526 = fixtures2526.copy().rename(columns={
#     'team_a':'team',
#     'fixture_team_a_score':'fixture_team_score',
#     'team_h':'opp_team',
#     'fixture_team_h_score':'fixture_opp_team_score',
#     'team_h_difficulty':'opp_team_difficulty',
#     'team_a_difficulty':'team_difficulty',
#     'away_team_name':'team_name',
#     'home_team_name':'opp_team_name',
#     'home_team_elo':'opp_team_elo',
#     'away_team_elo':'team_elo',
#     'team':'team_code'})
# all_fixtures2526 = pd.concat([home_fixtures2526,away_fixtures2526],join='inner',axis=0)

# # cross merge 2526 players with all gw fixtures
# playerfix2526 = fpl_loader.fpl_data[['player_name_id','team','position','season']].drop_duplicates().merge(fixtures2526['event'].drop_duplicates(), how='cross')
# all_playerfix2526 = playerfix2526.merge(fpl_loader.fpl_data, left_on=['player_name_id','event'],right_on=['player_name_id','gw'],suffixes=('','_gw'),how='left')
# current_year_players_allfixtures = all_playerfix2526.merge(all_fixtures2526, left_on=['event','team'],right_on=['event','team_name'],suffixes=('','_fixtures'),validate='many_to_one')
# current_year_players_allfixtures.info()

# %%
#Create DF from FPL API Request
import json
import requests
from datetime import datetime
season = 20252026

headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
get=requests.get("https://fantasy.premierleague.com/api/bootstrap-static/", headers=headers, timeout=5)
data=json.loads(get.text)

#player_raw = Summary stats for each player for the 202/26 season
cols=list(data['elements'][0].keys())
player_raw = pd.DataFrame(data['elements'], columns = cols)
player = player_raw[['web_name','id','team','element_type','first_name','second_name']]

# for each player, get their historical data for each gameweek
season_data = []
max_player = len(set(player['id']))
for element_id in set(player['id']):
    headers={'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
    get=requests.get(f"https://fantasy.premierleague.com/api/element-summary/{element_id}/", headers=headers, timeout=5)
    element_data=json.loads(get.text)
    season_data.extend(element_data['history'])
    print(f"Loaded data for element_id: {element_id}/{max_player}")
seasondf2526_api = pd.DataFrame.from_dict(season_data)

seasondf2526_api = seasondf2526_api.merge(player, left_on='element', right_on='id', how='left', suffixes=('','_player'))
# Out:
# Loaded data for element_id: 1/759
# Loaded data for element_id: 2/759
# Loaded data for element_id: 3/759
# Loaded data for element_id: 4/759
# Loaded data for element_id: 5/759
# Loaded data for element_id: 6/759
# Loaded data for element_id: 7/759
# Loaded data for element_id: 8/759
# Loaded data for element_id: 9/759
# Loaded data for element_id: 10/759
# Loaded data for element_id: 11/759
# Loaded data for element_id: 12/759
# Loaded data for element_id: 13/759
# Loaded data for element_id: 14/759
# Loaded data for element_id: 15/759
# Loaded data for element_id: 16/759
# Loaded data for element_id: 17/759
# Loaded data for element_id: 18/759
# Loaded data for element_id: 19/759
# Loaded data for element_id: 20/759
# Loaded data for element_id: 21/759
# Loaded data for element_id: 22/759
# Loaded data for element_id: 23/759
# Loaded data for element_id: 24/759
# Loaded data for element_id: 25/759
# Loaded data for element_id: 26/759
# Loaded data for element_id: 27/759
# Loaded data for element_id: 28/759
# Loaded data for element_id: 29/759
# Loaded data for element_id: 30/759
# Loaded data for element_id: 31/759
# Loaded data for element_id: 32/759
# Loaded data for element_id: 33/759
# Loaded data for element_id: 34/759
# Loaded data for element_id: 35/759
# Loaded data for element_id: 36/759
# Loaded data for element_id: 37/759
# Loaded data for element_id: 38/759
# Loaded data for element_id: 39/759
# Loaded data for element_id: 40/759
# Loaded data for element_id: 41/759
# Loaded data for element_id: 42/759
# Loaded data for element_id: 43/759
# Loaded data for element_id: 44/759
# Loaded data for element_id: 45/759
# Loaded data for element_id: 46/759
# Loaded data for element_id: 47/759
# Loaded data for element_id: 48/759
# Loaded data for element_id: 49/759
# Loaded data for element_id: 50/759
# Loaded data for element_id: 51/759
# Loaded data for element_id: 52/759
# Loaded data for element_id: 53/759
# Loaded data for element_id: 54/759
# Loaded data for element_id: 55/759
# Loaded data for element_id: 56/759
# Loaded data for element_id: 57/759
# Loaded data for element_id: 58/759
# Loaded data for element_id: 59/759
# Loaded data for element_id: 60/759
# Loaded data for element_id: 61/759
# Loaded data for element_id: 62/759
# Loaded data for element_id: 63/759
# Loaded data for element_id: 64/759
# Loaded data for element_id: 65/759
# Loaded data for element_id: 66/759
# Loaded data for element_id: 67/759
# Loaded data for element_id: 68/759
# Loaded data for element_id: 69/759
# Loaded data for element_id: 70/759
# Loaded data for element_id: 71/759
# Loaded data for element_id: 72/759
# Loaded data for element_id: 73/759
# Loaded data for element_id: 74/759
# Loaded data for element_id: 75/759
# Loaded data for element_id: 76/759
# Loaded data for element_id: 77/759
# Loaded data for element_id: 78/759
# Loaded data for element_id: 79/759
# Loaded data for element_id: 80/759
# Loaded data for element_id: 81/759
# Loaded data for element_id: 82/759
# Loaded data for element_id: 83/759
# Loaded data for element_id: 84/759
# Loaded data for element_id: 85/759
# Loaded data for element_id: 86/759
# Loaded data for element_id: 87/759
# Loaded data for element_id: 88/759
# Loaded data for element_id: 89/759
# Loaded data for element_id: 90/759
# Loaded data for element_id: 91/759
# Loaded data for element_id: 92/759
# Loaded data for element_id: 93/759
# Loaded data for element_id: 94/759
# Loaded data for element_id: 95/759
# Loaded data for element_id: 96/759
# Loaded data for element_id: 97/759
# Loaded data for element_id: 98/759
# Loaded data for element_id: 99/759
# Loaded data for element_id: 100/759
# Loaded data for element_id: 101/759
# Loaded data for element_id: 102/759
# Loaded data for element_id: 103/759
# Loaded data for element_id: 104/759
# Loaded data for element_id: 105/759
# Loaded data for element_id: 106/759
# Loaded data for element_id: 107/759
# Loaded data for element_id: 108/759
# Loaded data for element_id: 109/759
# Loaded data for element_id: 110/759
# Loaded data for element_id: 111/759
# Loaded data for element_id: 112/759
# Loaded data for element_id: 113/759
# Loaded data for element_id: 114/759
# Loaded data for element_id: 115/759
# Loaded data for element_id: 116/759
# Loaded data for element_id: 117/759
# Loaded data for element_id: 118/759
# Loaded data for element_id: 119/759
# Loaded data for element_id: 120/759
# Loaded data for element_id: 121/759
# Loaded data for element_id: 122/759
# Loaded data for element_id: 123/759
# Loaded data for element_id: 124/759
# Loaded data for element_id: 125/759
# Loaded data for element_id: 126/759
# Loaded data for element_id: 127/759
# Loaded data for element_id: 128/759
# Loaded data for element_id: 129/759
# Loaded data for element_id: 130/759
# Loaded data for element_id: 131/759
# Loaded data for element_id: 132/759
# Loaded data for element_id: 133/759
# Loaded data for element_id: 134/759
# Loaded data for element_id: 135/759
# Loaded data for element_id: 136/759
# Loaded data for element_id: 137/759
# Loaded data for element_id: 138/759
# Loaded data for element_id: 139/759
# Loaded data for element_id: 140/759
# Loaded data for element_id: 141/759
# Loaded data for element_id: 142/759
# Loaded data for element_id: 143/759
# Loaded data for element_id: 144/759
# Loaded data for element_id: 145/759
# Loaded data for element_id: 146/759
# Loaded data for element_id: 147/759
# Loaded data for element_id: 148/759
# Loaded data for element_id: 149/759
# Loaded data for element_id: 150/759
# Loaded data for element_id: 151/759
# Loaded data for element_id: 152/759
# Loaded data for element_id: 153/759
# Loaded data for element_id: 154/759
# Loaded data for element_id: 155/759
# Loaded data for element_id: 156/759
# Loaded data for element_id: 157/759
# Loaded data for element_id: 158/759
# Loaded data for element_id: 159/759
# Loaded data for element_id: 160/759
# Loaded data for element_id: 161/759
# Loaded data for element_id: 162/759
# Loaded data for element_id: 163/759
# Loaded data for element_id: 164/759
# Loaded data for element_id: 165/759
# Loaded data for element_id: 166/759
# Loaded data for element_id: 167/759
# Loaded data for element_id: 168/759
# Loaded data for element_id: 169/759
# Loaded data for element_id: 170/759
# Loaded data for element_id: 171/759
# Loaded data for element_id: 172/759
# Loaded data for element_id: 173/759
# Loaded data for element_id: 174/759
# Loaded data for element_id: 175/759
# Loaded data for element_id: 176/759
# Loaded data for element_id: 177/759
# Loaded data for element_id: 178/759
# Loaded data for element_id: 179/759
# Loaded data for element_id: 180/759
# Loaded data for element_id: 181/759
# Loaded data for element_id: 182/759
# Loaded data for element_id: 183/759
# Loaded data for element_id: 184/759
# Loaded data for element_id: 185/759
# Loaded data for element_id: 186/759
# Loaded data for element_id: 187/759
# Loaded data for element_id: 188/759
# Loaded data for element_id: 189/759
# Loaded data for element_id: 190/759
# Loaded data for element_id: 191/759
# Loaded data for element_id: 192/759
# Loaded data for element_id: 193/759
# Loaded data for element_id: 194/759
# Loaded data for element_id: 195/759
# Loaded data for element_id: 196/759
# Loaded data for element_id: 197/759
# Loaded data for element_id: 198/759
# Loaded data for element_id: 199/759
# Loaded data for element_id: 200/759
# Loaded data for element_id: 201/759
# Loaded data for element_id: 202/759
# Loaded data for element_id: 203/759
# Loaded data for element_id: 204/759
# Loaded data for element_id: 205/759
# Loaded data for element_id: 206/759
# Loaded data for element_id: 207/759
# Loaded data for element_id: 208/759
# Loaded data for element_id: 209/759
# Loaded data for element_id: 210/759
# Loaded data for element_id: 211/759
# Loaded data for element_id: 212/759
# Loaded data for element_id: 213/759
# Loaded data for element_id: 214/759
# Loaded data for element_id: 215/759
# Loaded data for element_id: 216/759
# Loaded data for element_id: 217/759
# Loaded data for element_id: 218/759
# Loaded data for element_id: 219/759
# Loaded data for element_id: 220/759
# Loaded data for element_id: 221/759
# Loaded data for element_id: 222/759
# Loaded data for element_id: 223/759
# Loaded data for element_id: 224/759
# Loaded data for element_id: 225/759
# Loaded data for element_id: 226/759
# Loaded data for element_id: 227/759
# Loaded data for element_id: 228/759
# Loaded data for element_id: 229/759
# Loaded data for element_id: 230/759
# Loaded data for element_id: 231/759
# Loaded data for element_id: 232/759
# Loaded data for element_id: 233/759
# Loaded data for element_id: 234/759
# Loaded data for element_id: 235/759
# Loaded data for element_id: 236/759
# Loaded data for element_id: 237/759
# Loaded data for element_id: 238/759
# Loaded data for element_id: 239/759
# Loaded data for element_id: 240/759
# Loaded data for element_id: 241/759
# Loaded data for element_id: 242/759
# Loaded data for element_id: 243/759
# Loaded data for element_id: 244/759
# Loaded data for element_id: 245/759
# Loaded data for element_id: 246/759
# Loaded data for element_id: 247/759
# Loaded data for element_id: 248/759
# Loaded data for element_id: 249/759
# Loaded data for element_id: 250/759
# Loaded data for element_id: 251/759
# Loaded data for element_id: 252/759
# Loaded data for element_id: 253/759
# Loaded data for element_id: 254/759
# Loaded data for element_id: 255/759
# Loaded data for element_id: 256/759
# Loaded data for element_id: 257/759
# Loaded data for element_id: 258/759
# Loaded data for element_id: 259/759
# Loaded data for element_id: 260/759
# Loaded data for element_id: 261/759
# Loaded data for element_id: 262/759
# Loaded data for element_id: 263/759
# Loaded data for element_id: 264/759
# Loaded data for element_id: 265/759
# Loaded data for element_id: 266/759
# Loaded data for element_id: 267/759
# Loaded data for element_id: 268/759
# Loaded data for element_id: 269/759
# Loaded data for element_id: 270/759
# Loaded data for element_id: 271/759
# Loaded data for element_id: 272/759
# Loaded data for element_id: 273/759
# Loaded data for element_id: 274/759
# Loaded data for element_id: 275/759
# Loaded data for element_id: 276/759
# Loaded data for element_id: 277/759
# Loaded data for element_id: 278/759
# Loaded data for element_id: 279/759
# Loaded data for element_id: 280/759
# Loaded data for element_id: 281/759
# Loaded data for element_id: 282/759
# Loaded data for element_id: 283/759
# Loaded data for element_id: 284/759
# Loaded data for element_id: 285/759
# Loaded data for element_id: 286/759
# Loaded data for element_id: 287/759
# Loaded data for element_id: 288/759
# Loaded data for element_id: 289/759
# Loaded data for element_id: 290/759
# Loaded data for element_id: 291/759
# Loaded data for element_id: 292/759
# Loaded data for element_id: 293/759
# Loaded data for element_id: 294/759
# Loaded data for element_id: 295/759
# Loaded data for element_id: 296/759
# Loaded data for element_id: 297/759
# Loaded data for element_id: 298/759
# Loaded data for element_id: 299/759
# Loaded data for element_id: 300/759
# Loaded data for element_id: 301/759
# Loaded data for element_id: 302/759
# Loaded data for element_id: 303/759
# Loaded data for element_id: 304/759
# Loaded data for element_id: 305/759
# Loaded data for element_id: 306/759
# Loaded data for element_id: 307/759
# Loaded data for element_id: 308/759
# Loaded data for element_id: 309/759
# Loaded data for element_id: 310/759
# Loaded data for element_id: 311/759
# Loaded data for element_id: 312/759
# Loaded data for element_id: 313/759
# Loaded data for element_id: 314/759
# Loaded data for element_id: 315/759
# Loaded data for element_id: 316/759
# Loaded data for element_id: 317/759
# Loaded data for element_id: 318/759
# Loaded data for element_id: 319/759
# Loaded data for element_id: 320/759
# Loaded data for element_id: 321/759
# Loaded data for element_id: 322/759
# Loaded data for element_id: 323/759
# Loaded data for element_id: 324/759
# Loaded data for element_id: 325/759
# Loaded data for element_id: 326/759
# Loaded data for element_id: 327/759
# Loaded data for element_id: 328/759
# Loaded data for element_id: 329/759
# Loaded data for element_id: 330/759
# Loaded data for element_id: 331/759
# Loaded data for element_id: 332/759
# Loaded data for element_id: 333/759
# Loaded data for element_id: 334/759
# Loaded data for element_id: 335/759
# Loaded data for element_id: 336/759
# Loaded data for element_id: 337/759
# Loaded data for element_id: 338/759
# Loaded data for element_id: 339/759
# Loaded data for element_id: 340/759
# Loaded data for element_id: 341/759
# Loaded data for element_id: 342/759
# Loaded data for element_id: 343/759
# Loaded data for element_id: 344/759
# Loaded data for element_id: 345/759
# Loaded data for element_id: 346/759
# Loaded data for element_id: 347/759
# Loaded data for element_id: 348/759
# Loaded data for element_id: 349/759
# Loaded data for element_id: 350/759
# Loaded data for element_id: 351/759
# Loaded data for element_id: 352/759
# Loaded data for element_id: 353/759
# Loaded data for element_id: 354/759
# Loaded data for element_id: 355/759
# Loaded data for element_id: 356/759
# Loaded data for element_id: 357/759
# Loaded data for element_id: 358/759
# Loaded data for element_id: 359/759
# Loaded data for element_id: 360/759
# Loaded data for element_id: 361/759
# Loaded data for element_id: 362/759
# Loaded data for element_id: 363/759
# Loaded data for element_id: 364/759
# Loaded data for element_id: 365/759
# Loaded data for element_id: 366/759
# Loaded data for element_id: 367/759
# Loaded data for element_id: 368/759
# Loaded data for element_id: 369/759
# Loaded data for element_id: 370/759
# Loaded data for element_id: 371/759
# Loaded data for element_id: 372/759
# Loaded data for element_id: 373/759
# Loaded data for element_id: 374/759
# Loaded data for element_id: 375/759
# Loaded data for element_id: 376/759
# Loaded data for element_id: 377/759
# Loaded data for element_id: 378/759
# Loaded data for element_id: 379/759
# Loaded data for element_id: 380/759
# Loaded data for element_id: 381/759
# Loaded data for element_id: 382/759
# Loaded data for element_id: 383/759
# Loaded data for element_id: 384/759
# Loaded data for element_id: 385/759
# Loaded data for element_id: 386/759
# Loaded data for element_id: 387/759
# Loaded data for element_id: 388/759
# Loaded data for element_id: 389/759
# Loaded data for element_id: 390/759
# Loaded data for element_id: 391/759
# Loaded data for element_id: 392/759
# Loaded data for element_id: 393/759
# Loaded data for element_id: 394/759
# Loaded data for element_id: 395/759
# Loaded data for element_id: 396/759
# Loaded data for element_id: 397/759
# Loaded data for element_id: 398/759
# Loaded data for element_id: 399/759
# Loaded data for element_id: 400/759
# Loaded data for element_id: 401/759
# Loaded data for element_id: 402/759
# Loaded data for element_id: 403/759
# Loaded data for element_id: 404/759
# Loaded data for element_id: 405/759
# Loaded data for element_id: 406/759
# Loaded data for element_id: 407/759
# Loaded data for element_id: 408/759
# Loaded data for element_id: 409/759
# Loaded data for element_id: 410/759
# Loaded data for element_id: 411/759
# Loaded data for element_id: 412/759
# Loaded data for element_id: 413/759
# Loaded data for element_id: 414/759
# Loaded data for element_id: 415/759
# Loaded data for element_id: 416/759
# Loaded data for element_id: 417/759
# Loaded data for element_id: 418/759
# Loaded data for element_id: 419/759
# Loaded data for element_id: 420/759
# Loaded data for element_id: 421/759
# Loaded data for element_id: 422/759
# Loaded data for element_id: 423/759
# Loaded data for element_id: 424/759
# Loaded data for element_id: 425/759
# Loaded data for element_id: 426/759
# Loaded data for element_id: 427/759
# Loaded data for element_id: 428/759
# Loaded data for element_id: 429/759
# Loaded data for element_id: 430/759
# Loaded data for element_id: 431/759
# Loaded data for element_id: 432/759
# Loaded data for element_id: 433/759
# Loaded data for element_id: 434/759
# Loaded data for element_id: 435/759
# Loaded data for element_id: 436/759
# Loaded data for element_id: 437/759
# Loaded data for element_id: 438/759
# Loaded data for element_id: 439/759
# Loaded data for element_id: 440/759
# Loaded data for element_id: 441/759
# Loaded data for element_id: 442/759
# Loaded data for element_id: 443/759
# Loaded data for element_id: 444/759
# Loaded data for element_id: 445/759
# Loaded data for element_id: 446/759
# Loaded data for element_id: 447/759
# Loaded data for element_id: 448/759
# Loaded data for element_id: 449/759
# Loaded data for element_id: 450/759
# Loaded data for element_id: 451/759
# Loaded data for element_id: 452/759
# Loaded data for element_id: 453/759
# Loaded data for element_id: 454/759
# Loaded data for element_id: 455/759
# Loaded data for element_id: 456/759
# Loaded data for element_id: 457/759
# Loaded data for element_id: 458/759
# Loaded data for element_id: 459/759
# Loaded data for element_id: 460/759
# Loaded data for element_id: 461/759
# Loaded data for element_id: 462/759
# Loaded data for element_id: 463/759
# Loaded data for element_id: 464/759
# Loaded data for element_id: 465/759
# Loaded data for element_id: 466/759
# Loaded data for element_id: 467/759
# Loaded data for element_id: 468/759
# Loaded data for element_id: 469/759
# Loaded data for element_id: 470/759
# Loaded data for element_id: 471/759
# Loaded data for element_id: 472/759
# Loaded data for element_id: 473/759
# Loaded data for element_id: 474/759
# Loaded data for element_id: 475/759
# Loaded data for element_id: 476/759
# Loaded data for element_id: 477/759
# Loaded data for element_id: 478/759
# Loaded data for element_id: 479/759
# Loaded data for element_id: 480/759
# Loaded data for element_id: 481/759
# Loaded data for element_id: 482/759
# Loaded data for element_id: 483/759
# Loaded data for element_id: 484/759
# Loaded data for element_id: 485/759
# Loaded data for element_id: 486/759
# Loaded data for element_id: 487/759
# Loaded data for element_id: 488/759
# Loaded data for element_id: 489/759
# Loaded data for element_id: 490/759
# Loaded data for element_id: 491/759
# Loaded data for element_id: 492/759
# Loaded data for element_id: 493/759
# Loaded data for element_id: 494/759
# Loaded data for element_id: 495/759
# Loaded data for element_id: 496/759
# Loaded data for element_id: 497/759
# Loaded data for element_id: 498/759
# Loaded data for element_id: 499/759
# Loaded data for element_id: 500/759
# Loaded data for element_id: 501/759
# Loaded data for element_id: 502/759
# Loaded data for element_id: 503/759
# Loaded data for element_id: 504/759
# Loaded data for element_id: 505/759
# Loaded data for element_id: 506/759
# Loaded data for element_id: 507/759
# Loaded data for element_id: 508/759
# Loaded data for element_id: 509/759
# Loaded data for element_id: 510/759
# Loaded data for element_id: 511/759
# Loaded data for element_id: 512/759
# Loaded data for element_id: 513/759
# Loaded data for element_id: 514/759
# Loaded data for element_id: 515/759
# Loaded data for element_id: 516/759
# Loaded data for element_id: 517/759
# Loaded data for element_id: 518/759
# Loaded data for element_id: 519/759
# Loaded data for element_id: 520/759
# Loaded data for element_id: 521/759
# Loaded data for element_id: 522/759
# Loaded data for element_id: 523/759
# Loaded data for element_id: 524/759
# Loaded data for element_id: 525/759
# Loaded data for element_id: 526/759
# Loaded data for element_id: 527/759
# Loaded data for element_id: 528/759
# Loaded data for element_id: 529/759
# Loaded data for element_id: 530/759
# Loaded data for element_id: 531/759
# Loaded data for element_id: 532/759
# Loaded data for element_id: 533/759
# Loaded data for element_id: 534/759
# Loaded data for element_id: 535/759
# Loaded data for element_id: 536/759
# Loaded data for element_id: 537/759
# Loaded data for element_id: 538/759
# Loaded data for element_id: 539/759
# Loaded data for element_id: 540/759
# Loaded data for element_id: 541/759
# Loaded data for element_id: 542/759
# Loaded data for element_id: 543/759
# Loaded data for element_id: 544/759
# Loaded data for element_id: 545/759
# Loaded data for element_id: 546/759
# Loaded data for element_id: 547/759
# Loaded data for element_id: 548/759
# Loaded data for element_id: 549/759
# Loaded data for element_id: 550/759
# Loaded data for element_id: 551/759
# Loaded data for element_id: 552/759
# Loaded data for element_id: 553/759
# Loaded data for element_id: 554/759
# Loaded data for element_id: 555/759
# Loaded data for element_id: 556/759
# Loaded data for element_id: 557/759
# Loaded data for element_id: 558/759
# Loaded data for element_id: 559/759
# Loaded data for element_id: 560/759
# Loaded data for element_id: 561/759
# Loaded data for element_id: 562/759
# Loaded data for element_id: 563/759
# Loaded data for element_id: 564/759
# Loaded data for element_id: 565/759
# Loaded data for element_id: 566/759
# Loaded data for element_id: 567/759
# Loaded data for element_id: 568/759
# Loaded data for element_id: 569/759
# Loaded data for element_id: 570/759
# Loaded data for element_id: 571/759
# Loaded data for element_id: 572/759
# Loaded data for element_id: 573/759
# Loaded data for element_id: 574/759
# Loaded data for element_id: 575/759
# Loaded data for element_id: 576/759
# Loaded data for element_id: 577/759
# Loaded data for element_id: 578/759
# Loaded data for element_id: 579/759
# Loaded data for element_id: 580/759
# Loaded data for element_id: 581/759
# Loaded data for element_id: 582/759
# Loaded data for element_id: 583/759
# Loaded data for element_id: 584/759
# Loaded data for element_id: 585/759
# Loaded data for element_id: 586/759
# Loaded data for element_id: 587/759
# Loaded data for element_id: 588/759
# Loaded data for element_id: 589/759
# Loaded data for element_id: 590/759
# Loaded data for element_id: 591/759
# Loaded data for element_id: 592/759
# Loaded data for element_id: 593/759
# Loaded data for element_id: 594/759
# Loaded data for element_id: 595/759
# Loaded data for element_id: 596/759
# Loaded data for element_id: 597/759
# Loaded data for element_id: 598/759
# Loaded data for element_id: 599/759
# Loaded data for element_id: 600/759
# Loaded data for element_id: 601/759
# Loaded data for element_id: 602/759
# Loaded data for element_id: 603/759
# Loaded data for element_id: 604/759
# Loaded data for element_id: 605/759
# Loaded data for element_id: 606/759
# Loaded data for element_id: 607/759
# Loaded data for element_id: 608/759
# Loaded data for element_id: 609/759
# Loaded data for element_id: 610/759
# Loaded data for element_id: 611/759
# Loaded data for element_id: 612/759
# Loaded data for element_id: 613/759
# Loaded data for element_id: 614/759
# Loaded data for element_id: 615/759
# Loaded data for element_id: 616/759
# Loaded data for element_id: 617/759
# Loaded data for element_id: 618/759
# Loaded data for element_id: 619/759
# Loaded data for element_id: 620/759
# Loaded data for element_id: 621/759
# Loaded data for element_id: 622/759
# Loaded data for element_id: 623/759
# Loaded data for element_id: 624/759
# Loaded data for element_id: 625/759
# Loaded data for element_id: 626/759
# Loaded data for element_id: 627/759
# Loaded data for element_id: 628/759
# Loaded data for element_id: 629/759
# Loaded data for element_id: 630/759
# Loaded data for element_id: 631/759
# Loaded data for element_id: 632/759
# Loaded data for element_id: 633/759
# Loaded data for element_id: 634/759
# Loaded data for element_id: 635/759
# Loaded data for element_id: 636/759
# Loaded data for element_id: 637/759
# Loaded data for element_id: 638/759
# Loaded data for element_id: 639/759
# Loaded data for element_id: 640/759
# Loaded data for element_id: 641/759
# Loaded data for element_id: 642/759
# Loaded data for element_id: 643/759
# Loaded data for element_id: 644/759
# Loaded data for element_id: 645/759
# Loaded data for element_id: 646/759
# Loaded data for element_id: 647/759
# Loaded data for element_id: 648/759
# Loaded data for element_id: 649/759
# Loaded data for element_id: 650/759
# Loaded data for element_id: 651/759
# Loaded data for element_id: 652/759
# Loaded data for element_id: 653/759
# Loaded data for element_id: 654/759
# Loaded data for element_id: 655/759
# Loaded data for element_id: 656/759
# Loaded data for element_id: 657/759
# Loaded data for element_id: 658/759
# Loaded data for element_id: 659/759
# Loaded data for element_id: 660/759
# Loaded data for element_id: 661/759
# Loaded data for element_id: 662/759
# Loaded data for element_id: 663/759
# Loaded data for element_id: 664/759
# Loaded data for element_id: 665/759
# Loaded data for element_id: 666/759
# Loaded data for element_id: 667/759
# Loaded data for element_id: 668/759
# Loaded data for element_id: 669/759
# Loaded data for element_id: 670/759
# Loaded data for element_id: 671/759
# Loaded data for element_id: 672/759
# Loaded data for element_id: 673/759
# Loaded data for element_id: 674/759
# Loaded data for element_id: 675/759
# Loaded data for element_id: 676/759
# Loaded data for element_id: 677/759
# Loaded data for element_id: 678/759
# Loaded data for element_id: 679/759
# Loaded data for element_id: 680/759
# Loaded data for element_id: 681/759
# Loaded data for element_id: 682/759
# Loaded data for element_id: 683/759
# Loaded data for element_id: 684/759
# Loaded data for element_id: 685/759
# Loaded data for element_id: 686/759
# Loaded data for element_id: 687/759
# Loaded data for element_id: 688/759
# Loaded data for element_id: 689/759
# Loaded data for element_id: 690/759
# Loaded data for element_id: 691/759
# Loaded data for element_id: 692/759
# Loaded data for element_id: 693/759
# Loaded data for element_id: 694/759
# Loaded data for element_id: 695/759
# Loaded data for element_id: 696/759
# Loaded data for element_id: 697/759
# Loaded data for element_id: 698/759
# Loaded data for element_id: 699/759
# Loaded data for element_id: 700/759
# Loaded data for element_id: 701/759
# Loaded data for element_id: 702/759
# Loaded data for element_id: 703/759
# Loaded data for element_id: 704/759
# Loaded data for element_id: 705/759
# Loaded data for element_id: 706/759
# Loaded data for element_id: 707/759
# Loaded data for element_id: 708/759
# Loaded data for element_id: 709/759
# Loaded data for element_id: 710/759
# Loaded data for element_id: 711/759
# Loaded data for element_id: 712/759
# Loaded data for element_id: 713/759
# Loaded data for element_id: 714/759
# Loaded data for element_id: 715/759
# Loaded data for element_id: 716/759
# Loaded data for element_id: 717/759
# Loaded data for element_id: 718/759
# Loaded data for element_id: 719/759
# Loaded data for element_id: 720/759
# Loaded data for element_id: 721/759
# Loaded data for element_id: 722/759
# Loaded data for element_id: 723/759
# Loaded data for element_id: 724/759
# Loaded data for element_id: 725/759
# Loaded data for element_id: 726/759
# Loaded data for element_id: 727/759
# Loaded data for element_id: 728/759
# Loaded data for element_id: 729/759
# Loaded data for element_id: 730/759
# Loaded data for element_id: 731/759
# Loaded data for element_id: 732/759
# Loaded data for element_id: 733/759
# Loaded data for element_id: 734/759
# Loaded data for element_id: 735/759
# Loaded data for element_id: 736/759
# Loaded data for element_id: 737/759
# Loaded data for element_id: 738/759
# Loaded data for element_id: 739/759
# Loaded data for element_id: 740/759
# Loaded data for element_id: 741/759
# Loaded data for element_id: 742/759
# Loaded data for element_id: 743/759
# Loaded data for element_id: 744/759
# Loaded data for element_id: 745/759
# Loaded data for element_id: 746/759
# Loaded data for element_id: 747/759
# Loaded data for element_id: 748/759
# Loaded data for element_id: 749/759
# Loaded data for element_id: 750/759
# Loaded data for element_id: 751/759
# Loaded data for element_id: 752/759
# Loaded data for element_id: 753/759
# Loaded data for element_id: 754/759
# Loaded data for element_id: 755/759
# Loaded data for element_id: 756/759
# Loaded data for element_id: 757/759
# Loaded data for element_id: 758/759
# Loaded data for element_id: 759/759

# %%
seasondf2526_api.shape
# Out:
# (11090, 47)

# %%
[col for col in seasondf2526_api.columns if col not in fpl2425.columns]
# Out:
# ['clearances_blocks_interceptions',
#  'recoveries',
#  'tackles',
#  'defensive_contribution',
#  'web_name',
#  'id',
#  'element_type',
#  'first_name',
#  'second_name']

# %%
[col for col in fpl2425.columns if col not in seasondf2526_api.columns]
# Out:
# ['Unnamed: 0',
#  'player_name_id',
#  'position',
#  'xP',
#  'gw',
#  'mng_clean_sheets',
#  'mng_draw',
#  'mng_goals_scored',
#  'mng_loss',
#  'mng_underdog_draw',
#  'mng_underdog_win',
#  'mng_win',
#  'season']

# %%
### Update fixtures here: https://github.com/vaastav/Fantasy-Premier-League/blob/master/data/2025-26/fixtures.csv

url = "https://fantasy.premierleague.com/api/fixtures/"
response = requests.get(url)
response.raise_for_status()
fix2526 = pd.DataFrame(response.json())

fpl_loader = FPLDataLoader(
    season=20252026,
    gw_df=seasondf2526_api,
    fixtures_df=fix2526
)

fpl2526 = fpl_loader.load_fpl_data()
fix_ = fpl_loader.load_fixtures()
fixtures2526 = fpl_loader.add_elo_to_fixtures()
merged2526 = fpl_loader.merge_data()

#one fixture each for home & away
home_fixtures2526 = fixtures2526.copy().rename(columns={
    'team_a':'opp_team',
    'fixture_team_a_score':'fixture_opp_team_score',
    'team_h':'team',
    'fixture_team_h_score':'fixture_team_score',
    'team_h_difficulty':'team_difficulty',
    'team_a_difficulty':'opp_team_difficulty',
    'away_team_name':'opp_team_name',
    'home_team_name':'team_name',
    'home_team_elo':'team_elo',
    'away_team_elo':'opp_team_elo',
    'team':'team_code'})
away_fixtures2526 = fixtures2526.copy().rename(columns={
    'team_a':'team',
    'fixture_team_a_score':'fixture_team_score',
    'team_h':'opp_team',
    'fixture_team_h_score':'fixture_opp_team_score',
    'team_h_difficulty':'opp_team_difficulty',
    'team_a_difficulty':'team_difficulty',
    'away_team_name':'team_name',
    'home_team_name':'opp_team_name',
    'home_team_elo':'opp_team_elo',
    'away_team_elo':'team_elo',
    'team':'team_code'})
all_fixtures2526 = pd.concat([home_fixtures2526,away_fixtures2526],join='inner',axis=0)

# cross merge 2526 players with all gw fixtures
playerfix2526 = fpl_loader.fpl_data[['player_name_id','team','position','season']].drop_duplicates().merge(fixtures2526['event'].drop_duplicates(), how='cross')
all_playerfix2526 = playerfix2526.merge(fpl_loader.fpl_data, left_on=['player_name_id','event'],right_on=['player_name_id','gw'],suffixes=('','_gw'),how='left')
current_year_players_allfixtures = all_playerfix2526.merge(all_fixtures2526, left_on=['event','team'],right_on=['event','team'],suffixes=('','_fixtures'),validate='many_to_one')
current_year_players_allfixtures.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28842 entries, 0 to 28841
# Data columns (total 75 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   player_name_id              28842 non-null  object
#  1   team                        28842 non-null  int64
#  2   position                    28842 non-null  object
#  3   season                      28842 non-null  int64
#  4   event                       28842 non-null  int64
#  5   element                     11090 non-null  float64
#  6   fixture                     11090 non-null  float64
#  7   opponent_team               11090 non-null  float64
#  8   total_points                11090 non-null  float64
#  9   was_home                    11090 non-null  object
#  10  kickoff_time                11090 non-null  object
#  11  team_h_score                11013 non-null  float64
#  12  team_a_score                11013 non-null  float64
#  13  round                       11090 non-null  float64
#  14  modified                    11090 non-null  object
#  15  minutes                     11090 non-null  float64
#  16  goals_scored                11090 non-null  float64
#  17  assists                     11090 non-null  float64
#  18  clean_sheets                11090 non-null  float64
#  19  goals_conceded              11090 non-null  float64
#  20  own_goals                   11090 non-null  float64
#  21  penalties_saved             11090 non-null  float64
#  22  penalties_missed            11090 non-null  float64
#  23  yellow_cards                11090 non-null  float64
#  24  red_cards                   11090 non-null  float64
#  25  saves                       11090 non-null  float64
#  26  bonus                       11090 non-null  float64
#  27  bps                         11090 non-null  float64
#  28  influence                   11090 non-null  object
#  29  creativity                  11090 non-null  object
#  30  threat                      11090 non-null  object
#  31  ict_index                   11090 non-null  object
#  32  cbi                         11090 non-null  float64
#  33  recoveries                  11090 non-null  float64
#  34  tackles                     11090 non-null  float64
#  35  defensive_contribution      11090 non-null  float64
#  36  starts                      11090 non-null  float64
#  37  expected_goals              11090 non-null  float64
#  38  expected_assists            11090 non-null  float64
#  39  expected_goal_involvements  11090 non-null  float64
#  40  expected_goals_conceded     11090 non-null  float64
#  41  value                       11090 non-null  float64
#  42  transfers_balance           11090 non-null  float64
#  43  selected                    11090 non-null  float64
#  44  transfers_in                11090 non-null  float64
#  45  transfers_out               11090 non-null  float64
#  46  web_name                    11090 non-null  object
#  47  id                          11090 non-null  float64
#  48  team_gw                     11090 non-null  float64
#  49  element_type                11090 non-null  float64
#  50  first_name                  11090 non-null  object
#  51  second_name                 11090 non-null  object
#  52  gw                          11090 non-null  float64
#  53  position_gw                 11090 non-null  object
#  54  season_gw                   11090 non-null  float64
#  55  fixture_code                28842 non-null  int64
#  56  finished                    28842 non-null  bool
#  57  finished_provisional        28842 non-null  bool
#  58  fixture_id                  28842 non-null  int64
#  59  fixture_kickoff_time        28842 non-null  object
#  60  fixture_minutes             28842 non-null  int64
#  61  provisional_start_time      28842 non-null  bool
#  62  fixture_started             28842 non-null  bool
#  63  opp_team                    28842 non-null  int64
#  64  fixture_opp_team_score      11308 non-null  float64
#  65  fixture_team_score          11308 non-null  float64
#  66  fixture_stats               28842 non-null  object
#  67  team_difficulty             28842 non-null  int64
#  68  opp_team_difficulty         28842 non-null  int64
#  69  pulse_id                    28842 non-null  int64
#  70  fixture_season              28842 non-null  int64
#  71  opp_team_name               28842 non-null  object
#  72  team_name                   28842 non-null  object
#  73  team_elo                    28842 non-null  float64
#  74  opp_team_elo                28842 non-null  float64
# dtypes: bool(4), float64(43), int64(11), object(17)
# memory usage: 15.7+ MB

# %%
all_fixtures2526[all_fixtures2526['team_name']=='Arsenal'][['event','team_name','team_elo','opp_team_name','opp_team_elo']].sort_values(by='event')
# Out:
#      event team_name     team_elo   opp_team_name  opp_team_elo
# 8        1   Arsenal  1222.618796         Man Utd   1020.755939
# 15       2   Arsenal  1227.384819           Leeds    935.959117
# 28       3   Arsenal  1230.533140       Liverpool   1245.914874
# 30       4   Arsenal  1220.975573   Nott'm Forest   1055.263315
# 49       5   Arsenal  1226.537530        Man City   1212.072723
# 58       6   Arsenal  1226.121440       Newcastle   1112.169940
# 62       7   Arsenal  1232.954405        West Ham    978.932350
# 76       8   Arsenal  1236.716818          Fulham   1030.309582
# 85       9   Arsenal  1241.388526  Crystal Palace   1097.674167
# 93      10   Arsenal  1247.472909         Burnley    910.489785
# 103     11   Arsenal  1249.986238      Sunderland   1036.153451
# 118     12   Arsenal  1244.506645           Spurs   1013.778114
# 129     13   Arsenal  1248.695856         Chelsea   1144.719414
# 133     14   Arsenal  1245.789428       Brentford   1063.038520
# 140     15   Arsenal  1250.966257     Aston Villa   1155.559851
# 153     16   Arsenal  1238.287242          Wolves    910.980759
# 166     17   Arsenal  1238.287242         Everton   1074.008124
# 176     18   Arsenal  1238.287242        Brighton   1097.247349
# 184     19   Arsenal  1238.287242     Aston Villa   1168.238866
# 193     20   Arsenal  1238.287242     Bournemouth   1047.255511
# 209     21   Arsenal  1238.287242       Liverpool   1182.480015
# 216     22   Arsenal  1238.287242   Nott'm Forest   1024.727305
# 228     23   Arsenal  1238.287242         Man Utd   1055.376630
# 231     24   Arsenal  1238.287242           Leeds    937.257537
# 248     25   Arsenal  1238.287242      Sunderland   1040.714054
# 258     26   Arsenal  1238.287242       Brentford   1046.298325
# 263     27   Arsenal  1238.287242           Spurs   1014.659045
# 278     28   Arsenal  1238.287242         Chelsea   1129.328649
# 287     29   Arsenal  1238.287242        Brighton   1097.247349
# 298     30   Arsenal  1238.287242         Everton   1074.008124
# 301     31   Arsenal  1238.287242          Wolves    910.980759
# 319     32   Arsenal  1238.287242     Bournemouth   1047.255511
# 322     33   Arsenal  1238.287242        Man City   1229.412872
# 339     34   Arsenal  1238.287242       Newcastle   1109.370861
# 348     35   Arsenal  1238.287242          Fulham   1033.139181
# 354     36   Arsenal  1238.287242        West Ham    981.844170
# 368     37   Arsenal  1238.287242         Burnley    880.966713
# 375     38   Arsenal  1238.287242  Crystal Palace   1097.043759

# %%
#current team rankings
current_gameweek=13
print(f"Gameweek{current_gameweek} team rankings")
all_fixtures2526[all_fixtures2526['event']==current_gameweek].sort_values(by='team_elo', ascending=False)[['team_name','team_elo']]
# Out:
# Gameweek13 team rankings
#           team_name     team_elo
# 129         Arsenal  1248.695856
# 121        Man City  1215.899334
# 127       Liverpool  1188.224105
# 129         Chelsea  1144.719414
# 128     Aston Villa  1142.222683
# 125  Crystal Palace  1105.961120
# 126        Brighton  1101.452851
# 123       Newcastle  1098.980975
# 122     Bournemouth  1065.801289
# 123         Everton  1063.896408
# 120       Brentford  1057.381830
# 125         Man Utd  1045.971106
# 126   Nott'm Forest  1034.981739
# 122      Sunderland  1030.901187
# 124          Fulham  1026.892057
# 124           Spurs  1009.588903
# 127        West Ham   980.813094
# 128          Wolves   922.344220
# 121           Leeds   918.161783
# 120         Burnley   895.747010

# %%
playergw = pd.concat([fpl1819,fpl1920,fpl2021,fpl2122,fpl2223,fpl2324,fpl2425,fpl2526],axis=0)
playergw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189087 entries, 0 to 11089
# Data columns (total 79 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   player_name_id                  189087 non-null  object
#  1   assists                         189087 non-null  int64
#  2   attempted_passes                21790 non-null   float64
#  3   big_chances_created             21790 non-null   float64
#  4   big_chances_missed              21790 non-null   float64
#  5   bonus                           189087 non-null  int64
#  6   bps                             189087 non-null  int64
#  7   clean_sheets                    189087 non-null  int64
#  8   cbi                             32880 non-null   float64
#  9   completed_passes                21790 non-null   float64
#  10  creativity                      189087 non-null  object
#  11  dribbles                        21790 non-null   float64
#  12  ea_index                        21790 non-null   float64
#  13  element                         189087 non-null  int64
#  14  errors_leading_to_goal          21790 non-null   float64
#  15  errors_leading_to_goal_attempt  21790 non-null   float64
#  16  fixture                         189087 non-null  int64
#  17  fouls                           21790 non-null   float64
#  18  goals_conceded                  189087 non-null  int64
#  19  goals_scored                    189087 non-null  int64
#  20  ict_index                       189087 non-null  object
#  21  id                              32880 non-null   float64
#  22  influence                       189087 non-null  object
#  23  key_passes                      21790 non-null   float64
#  24  kickoff_time                    189087 non-null  object
#  25  kickoff_time_formatted          21790 non-null   object
#  26  loaned_in                       21790 non-null   float64
#  27  loaned_out                      21790 non-null   float64
#  28  minutes                         189087 non-null  int64
#  29  offside                         21790 non-null   float64
#  30  open_play_crosses               21790 non-null   float64
#  31  opponent_team                   189087 non-null  int64
#  32  own_goals                       189087 non-null  int64
#  33  penalties_conceded              21790 non-null   float64
#  34  penalties_missed                189087 non-null  int64
#  35  penalties_saved                 189087 non-null  int64
#  36  recoveries                      32880 non-null   float64
#  37  red_cards                       189087 non-null  int64
#  38  round                           189087 non-null  int64
#  39  saves                           189087 non-null  int64
#  40  selected                        189087 non-null  int64
#  41  tackled                         21790 non-null   float64
#  42  tackles                         32880 non-null   float64
#  43  target_missed                   21790 non-null   float64
#  44  team_a_score                    188951 non-null  float64
#  45  team_h_score                    188951 non-null  float64
#  46  threat                          189087 non-null  object
#  47  total_points                    189087 non-null  int64
#  48  transfers_balance               189087 non-null  int64
#  49  transfers_in                    189087 non-null  int64
#  50  transfers_out                   189087 non-null  int64
#  51  value                           189087 non-null  int64
#  52  was_home                        189087 non-null  bool
#  53  winning_goals                   21790 non-null   float64
#  54  yellow_cards                    189087 non-null  int64
#  55  gw                              189087 non-null  int64
#  56  season                          189087 non-null  int64
#  57  position                        144737 non-null  object
#  58  team                            144737 non-null  object
#  59  xP                              133647 non-null  float64
#  60  expected_assists                94925 non-null   float64
#  61  expected_goal_involvements      94925 non-null   float64
#  62  expected_goals                  94925 non-null   float64
#  63  expected_goals_conceded         94925 non-null   float64
#  64  starts                          94925 non-null   float64
#  65  Unnamed: 0                      27605 non-null   float64
#  66  modified                        38695 non-null   object
#  67  mng_clean_sheets                13427 non-null   float64
#  68  mng_draw                        13427 non-null   float64
#  69  mng_goals_scored                13427 non-null   float64
#  70  mng_loss                        13427 non-null   float64
#  71  mng_underdog_draw               13427 non-null   float64
#  72  mng_underdog_win                13427 non-null   float64
#  73  mng_win                         13427 non-null   float64
#  74  defensive_contribution          11090 non-null   float64
#  75  web_name                        11090 non-null   object
#  76  element_type                    11090 non-null   float64
#  77  first_name                      11090 non-null   object
#  78  second_name                     11090 non-null   object
# dtypes: bool(1), float64(40), int64(25), object(13)
# memory usage: 114.1+ MB

# %%
fix = pd.concat([fixtures1819,fixtures1920,fixtures2021,fixtures2122,fixtures2223,fixtures2324,fixtures2425,fixtures2526],axis=0)
fix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3040 entries, 0 to 379
# Data columns (total 26 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   fixture_code                    3040 non-null   int64
#  1   deadline_time                   380 non-null    object
#  2   deadline_time_formatted         380 non-null    object
#  3   event                           3040 non-null   int64
#  4   event_day                       380 non-null    float64
#  5   finished                        3040 non-null   bool
#  6   finished_provisional            3040 non-null   bool
#  7   fixture_id                      3040 non-null   int64
#  8   fixture_kickoff_time            3040 non-null   object
#  9   fixture_kickoff_time_formatted  380 non-null    object
#  10  fixture_minutes                 3040 non-null   int64
#  11  provisional_start_time          3040 non-null   bool
#  12  fixture_started                 3040 non-null   bool
#  13  fixture_stats                   3040 non-null   object
#  14  team_a                          3040 non-null   int64
#  15  team_a_difficulty               3040 non-null   int64
#  16  fixture_team_a_score            2809 non-null   float64
#  17  team_h                          3040 non-null   int64
#  18  team_h_difficulty               3040 non-null   int64
#  19  fixture_team_h_score            2809 non-null   float64
#  20  fixture_season                  3040 non-null   int64
#  21  away_team_name                  3040 non-null   object
#  22  home_team_name                  3040 non-null   object
#  23  home_team_elo                   3040 non-null   float64
#  24  away_team_elo                   3040 non-null   float64
#  25  pulse_id                        2280 non-null   float64
# dtypes: bool(4), float64(6), int64(9), object(7)
# memory usage: 558.1+ KB

# %%
df = pd.concat([merged1819,merged1920,merged2021,merged2122,merged2223,merged2324,merged2425,merged2526],axis=0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 189087 entries, 0 to 11089
# Columns: 109 entries, player_name_id to second_name
# dtypes: bool(5), float64(48), int64(34), object(22)
# memory usage: 152.4+ MB

# %%
df_rest_of_current_season = pd.concat([df,current_year_players_allfixtures], axis=0)
df_rest_of_current_season = df_rest_of_current_season.drop_duplicates(subset=['player_name_id','season','gw','event'])
df_rest_of_current_season.pivot_table(index='season',values='event',aggfunc='count')
# Out:
#           event
# season
# 20182019  21134
# 20192020  22372
# 20202021  22875
# 20212022  23194
# 20222023  24922
# 20232024  28742
# 20242025  27231
# 20252026  28842

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Prepare data
d = df_rest_of_current_season.copy()
dt = d[(d['player_name_id'] == "Bukayo Saka")
    #    &(d['season']==20242025)
       ][['season', 'event', 'team_elo']].copy()

# Create combined season-gameweek label
dt['season_gw'] = dt['season'].astype(str) + '-GW' + dt['event'].astype(str)

# Create figure with better styling
plt.figure(figsize=(14, 6))
sns.set_style("whitegrid")

# Create lineplot with markers
sns.lineplot(data=dt, x='season_gw', y='team_elo', marker='o', linewidth=2, markersize=6)

# Enhance the plot
plt.title("Bukayo Saka's Team ELO Rating by Season & Gameweek", fontsize=14, fontweight='bold')
plt.xlabel("Season - Gameweek", fontsize=12)
plt.ylabel("Team ELO Rating", fontsize=12)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
d[(d['player_name_id'] == "Bukayo Saka")
       &(d['season']==20252026)
       ][['season','event', 'team_elo','total_points','opp_team_name']].sort_values(by='event')
# Out:
#         season  event     team_elo  total_points   opp_team_name
# 225   20252026      1  1222.618796           3.0         Man Utd
# 226   20252026      2  1227.384819           6.0           Leeds
# 227   20252026      3  1230.533140           0.0       Liverpool
# 228   20252026      4  1220.975573           0.0   Nott'm Forest
# 229   20252026      5  1226.537530           1.0        Man City
# 230   20252026      6  1226.121440           2.0       Newcastle
# 231   20252026      7  1232.954405           8.0        West Ham
# 232   20252026      8  1236.716818           7.0          Fulham
# 233   20252026      9  1241.388526           3.0  Crystal Palace
# 234   20252026     10  1247.472909           3.0         Burnley
# 235   20252026     11  1249.986238          12.0      Sunderland
# 236   20252026     12  1244.506645           4.0           Spurs
# 237   20252026     13  1248.695856           5.0         Chelsea
# 238   20252026     14  1245.789428           6.0       Brentford
# 239   20252026     15  1250.966257           4.0     Aston Villa
# 554   20252026     16  1238.287242           NaN          Wolves
# 590   20252026     17  1238.287242           NaN         Everton
# 626   20252026     18  1238.287242           NaN        Brighton
# 662   20252026     19  1238.287242           NaN     Aston Villa
# 698   20252026     20  1238.287242           NaN     Bournemouth
# 734   20252026     21  1238.287242           NaN       Liverpool
# 770   20252026     22  1238.287242           NaN   Nott'm Forest
# 806   20252026     23  1238.287242           NaN         Man Utd
# 842   20252026     24  1238.287242           NaN           Leeds
# 878   20252026     25  1238.287242           NaN      Sunderland
# 914   20252026     26  1238.287242           NaN       Brentford
# 950   20252026     27  1238.287242           NaN           Spurs
# 986   20252026     28  1238.287242           NaN         Chelsea
# 1022  20252026     29  1238.287242           NaN        Brighton
# 1058  20252026     30  1238.287242           NaN         Everton
# 1094  20252026     31  1238.287242           NaN          Wolves
# 1130  20252026     32  1238.287242           NaN     Bournemouth
# 1166  20252026     33  1238.287242           NaN        Man City
# 1202  20252026     34  1238.287242           NaN       Newcastle
# 1238  20252026     35  1238.287242           NaN          Fulham
# 1274  20252026     36  1238.287242           NaN        West Ham
# 1310  20252026     37  1238.287242           NaN         Burnley
# 1346  20252026     38  1238.287242           NaN  Crystal Palace

# %%
pd.set_option('display.max_rows', 150)
df_rest_of_current_season.groupby('season').agg('count').T
# Out:
# season                          20182019  20192020  20202021  20212022  \
# player_name_id                     21134     22372     22875     23194
# assists                            21134     22372     22875     23194
# attempted_passes                   21134         0         0         0
# big_chances_created                21134         0         0         0
# big_chances_missed                 21134         0         0         0
# bonus                              21134     22372     22875     23194
# bps                                21134     22372     22875     23194
# clean_sheets                       21134     22372     22875     23194
# cbi                                21134         0         0         0
# completed_passes                   21134         0         0         0
# creativity                         21134     22372     22875     23194
# dribbles                           21134         0         0         0
# ea_index                           21134         0         0         0
# element                            21134     22372     22875     23194
# errors_leading_to_goal             21134         0         0         0
# errors_leading_to_goal_attempt     21134         0         0         0
# fixture                            21134     22372     22875     23194
# fouls                              21134         0         0         0
# goals_conceded                     21134     22372     22875     23194
# goals_scored                       21134     22372     22875     23194
# ict_index                          21134     22372     22875     23194
# id                                 21134         0         0         0
# influence                          21134     22372     22875     23194
# key_passes                         21134         0         0         0
# kickoff_time                       21134     22372     22875     23194
# kickoff_time_formatted             21134         0         0         0
# loaned_in                          21134         0         0         0
# loaned_out                         21134         0         0         0
# minutes                            21134     22372     22875     23194
# offside                            21134         0         0         0
# open_play_crosses                  21134         0         0         0
# opponent_team                      21134     22372     22875     23194
# own_goals                          21134     22372     22875     23194
# penalties_conceded                 21134         0         0         0
# penalties_missed                   21134     22372     22875     23194
# penalties_saved                    21134     22372     22875     23194
# recoveries                         21134         0         0         0
# red_cards                          21134     22372     22875     23194
# round                              21134     22372     22875     23194
# saves                              21134     22372     22875     23194
# selected                           21134     22372     22875     23194
# tackled                            21134         0         0         0
# tackles                            21134         0         0         0
# target_missed                      21134         0         0         0
# team_a_score                       21134     22313     22875     23194
# team_h_score                       21134     22313     22875     23194
# threat                             21134     22372     22875     23194
# total_points                       21134     22372     22875     23194
# transfers_balance                  21134     22372     22875     23194
# transfers_in                       21134     22372     22875     23194
# transfers_out                      21134     22372     22875     23194
# value                              21134     22372     22875     23194
# was_home                           21134     22372     22875     23194
# winning_goals                      21134         0         0         0
# yellow_cards                       21134     22372     22875     23194
# gw                                 21134     22372     22875     23194
# fixture_code                       21134     22372     22875     23194
# deadline_time                      21134         0         0         0
# deadline_time_formatted            21134         0         0         0
# event                              21134     22372     22875     23194
# event_day                          21134         0         0         0
# finished                           21134     22372     22875     23194
# finished_provisional               21134     22372     22875     23194
# fixture_id                         21134     22372     22875     23194
# fixture_kickoff_time               21134     22372     22875     23194
# fixture_kickoff_time_formatted     21134         0         0         0
# fixture_minutes                    21134     22372     22875     23194
# provisional_start_time             21134     22372     22875     23194
# fixture_started                    21134     22372     22875     23194
# fixture_stats                      21134     22372     22875     23194
# team_a                             21134     22372     22875     23194
# team_a_difficulty                  21134     22372     22875     23194
# fixture_team_a_score               21134     22372     22875     23194
# team_h                             21134     22372     22875     23194
# team_h_difficulty                  21134     22372     22875     23194
# fixture_team_h_score               21134     22372     22875     23194
# fixture_season                     21134     22372     22875     23194
# away_team_name                     21134     22372     22875     23194
# home_team_name                     21134     22372     22875     23194
# home_team_elo                      21134     22372     22875     23194
# away_team_elo                      21134     22372     22875     23194
# team_name                          21134     22372     22875     23194
# team_elo                           21134     22372     22875     23194
# opp_team_name                      21134     22372     22875     23194
# opp_team_elo                       21134     22372     22875     23194
# position                               0         0     22875     23194
# team                                   0         0     22875     23194
# xP                                     0         0     22875     23194
# pulse_id                               0         0     22875     23194
# expected_assists                       0         0         0         0
# expected_goal_involvements             0         0         0         0
# expected_goals                         0         0         0         0
# expected_goals_conceded                0         0         0         0
# starts                                 0         0         0         0
# Unnamed: 0                             0         0         0         0
# modified                               0         0         0         0
# mng_clean_sheets                       0         0         0         0
# mng_draw                               0         0         0         0
# mng_goals_scored                       0         0         0         0
# mng_loss                               0         0         0         0
# mng_underdog_draw                      0         0         0         0
# mng_underdog_win                       0         0         0         0
# mng_win                                0         0         0         0
# defensive_contribution                 0         0         0         0
# web_name                               0         0         0         0
# element_type                           0         0         0         0
# first_name                             0         0         0         0
# second_name                            0         0         0         0
# team_gw                                0         0         0         0
# position_gw                            0         0         0         0
# season_gw                              0         0         0         0
# opp_team                               0         0         0         0
# fixture_opp_team_score                 0         0         0         0
# fixture_team_score                     0         0         0         0
# team_difficulty                        0         0         0         0
# opp_team_difficulty                    0         0         0         0
#
# season                          20222023  20232024  20242025  20252026
# player_name_id                     24922     28742     27231     28842
# assists                            24922     28742     27231     11090
# attempted_passes                       0         0         0         0
# big_chances_created                    0         0         0         0
# big_chances_missed                     0         0         0         0
# bonus                              24922     28742     27231     11090
# bps                                24922     28742     27231     11090
# clean_sheets                       24922     28742     27231     11090
# cbi                                    0         0         0     11090
# completed_passes                       0         0         0         0
# creativity                         24922     28742     27231     11090
# dribbles                               0         0         0         0
# ea_index                               0         0         0         0
# element                            24922     28742     27231     11090
# errors_leading_to_goal                 0         0         0         0
# errors_leading_to_goal_attempt         0         0         0         0
# fixture                            24922     28742     27231     11090
# fouls                                  0         0         0         0
# goals_conceded                     24922     28742     27231     11090
# goals_scored                       24922     28742     27231     11090
# ict_index                          24922     28742     27231     11090
# id                                     0         0         0     11090
# influence                          24922     28742     27231     11090
# key_passes                             0         0         0         0
# kickoff_time                       24922     28742     27231     11090
# kickoff_time_formatted                 0         0         0         0
# loaned_in                              0         0         0         0
# loaned_out                             0         0         0         0
# minutes                            24922     28742     27231     11090
# offside                                0         0         0         0
# open_play_crosses                      0         0         0         0
# opponent_team                      24922     28742     27231     11090
# own_goals                          24922     28742     27231     11090
# penalties_conceded                     0         0         0         0
# penalties_missed                   24922     28742     27231     11090
# penalties_saved                    24922     28742     27231     11090
# recoveries                             0         0         0     11090
# red_cards                          24922     28742     27231     11090
# round                              24922     28742     27231     11090
# saves                              24922     28742     27231     11090
# selected                           24922     28742     27231     11090
# tackled                                0         0         0         0
# tackles                                0         0         0     11090
# target_missed                          0         0         0         0
# team_a_score                       24922     28742     27231     11013
# team_h_score                       24922     28742     27231     11013
# threat                             24922     28742     27231     11090
# total_points                       24922     28742     27231     11090
# transfers_balance                  24922     28742     27231     11090
# transfers_in                       24922     28742     27231     11090
# transfers_out                      24922     28742     27231     11090
# value                              24922     28742     27231     11090
# was_home                           24922     28742     27231     11090
# winning_goals                          0         0         0         0
# yellow_cards                       24922     28742     27231     11090
# gw                                 24922     28742     27231     11090
# fixture_code                       24922     28742     27231     28842
# deadline_time                          0         0         0         0
# deadline_time_formatted                0         0         0         0
# event                              24922     28742     27231     28842
# event_day                              0         0         0         0
# finished                           24922     28742     27231     28842
# finished_provisional               24922     28742     27231     28842
# fixture_id                         24922     28742     27231     28842
# fixture_kickoff_time               24922     28742     27231     28842
# fixture_kickoff_time_formatted         0         0         0         0
# fixture_minutes                    24922     28742     27231     28842
# provisional_start_time             24922     28742     27231     28842
# fixture_started                    24922     28742     27231     28842
# fixture_stats                      24922     28742     27231     28842
# team_a                             24922     28742     27231     11090
# team_a_difficulty                  24922     28742     27231     11090
# fixture_team_a_score               24922     28742     27231     11013
# team_h                             24922     28742     27231     11090
# team_h_difficulty                  24922     28742     27231     11090
# fixture_team_h_score               24922     28742     27231     11013
# fixture_season                     24922     28742     27231     28842
# away_team_name                     24922     28742     27231     11090
# home_team_name                     24922     28742     27231     11090
# home_team_elo                      24922     28742     27231     11090
# away_team_elo                      24922     28742     27231     11090
# team_name                          24922     28742     27231     28842
# team_elo                           24922     28742     27231     28842
# opp_team_name                      24922     28742     27231     28842
# opp_team_elo                       24922     28742     27231     28842
# position                           24922     28742     27231     28842
# team                               24922     28742     27231     28842
# xP                                 24922     28742     27231         0
# pulse_id                           24922     28742     27231     28842
# expected_assists                   24922     28742     27231     11090
# expected_goal_involvements         24922     28742     27231     11090
# expected_goals                     24922     28742     27231     11090
# expected_goals_conceded            24922     28742     27231     11090
# starts                             24922     28742     27231     11090
# Unnamed: 0                             0         0     27231         0
# modified                               0         0     27231     11090
# mng_clean_sheets                       0         0     13053         0
# mng_draw                               0         0     13053         0
# mng_goals_scored                       0         0     13053         0
# mng_loss                               0         0     13053         0
# mng_underdog_draw                      0         0     13053         0
# mng_underdog_win                       0         0     13053         0
# mng_win                                0         0     13053         0
# defensive_contribution                 0         0         0     11090
# web_name                               0         0         0     11090
# element_type                           0         0         0     11090
# first_name                             0         0         0     11090
# second_name                            0         0         0     11090
# team_gw                                0         0         0         0
# position_gw                            0         0         0         0
# season_gw                              0         0         0         0
# opp_team                               0         0         0     17752
# fixture_opp_team_score                 0         0         0       295
# fixture_team_score                     0         0         0       295
# team_difficulty                        0         0         0     17752
# opp_team_difficulty                    0         0         0     17752

# %%
from DatabaseCreator import DatabaseCreator
import CJDH_local_settings

#Run Database Creator
if __name__ == "__main__":
    db_creator = DatabaseCreator(db_settings=CJDH_local_settings.local_settings['FPL_Points_Predictor'])
    fpl_engine = db_creator.get_engine_for("fpl_data_analysis")

# %%
#Add a new staging table & data into the database
playergw = df_rest_of_current_season[['player_name_id','element','value','season','event','fixture','total_points',
                         'minutes','goals_scored','assists','team_elo','opp_team_elo','position','bonus','bps',
                         'clean_sheets','goals_conceded','was_home','expected_assists','expected_goal_involvements',
                         'expected_goals','expected_goals_conceded','starts',
                         'cbi','defensive_contribution','recoveries','tackles',
                         'saves','team_name','opp_team_name']]

table_name = "playergw"

if __name__ == "__main__":
    db_creator.create_staging_table_then_insert_data(table_name, data=playergw)
    playergwdf = db_creator.table_to_df(table_name=table_name)
    print(playergwdf.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 199312 entries, 0 to 199311
# Data columns (total 30 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   player_name_id              199312 non-null  object
#  1   element                     181560 non-null  float64
#  2   value                       181560 non-null  float64
#  3   season                      199312 non-null  float64
#  4   event                       199312 non-null  float64
#  5   fixture                     181560 non-null  float64
#  6   total_points                181560 non-null  float64
#  7   minutes                     181560 non-null  float64
#  8   goals_scored                181560 non-null  float64
#  9   assists                     181560 non-null  float64
#  10  team_elo                    199312 non-null  float64
#  11  opp_team_elo                199312 non-null  float64
#  12  position                    155806 non-null  object
#  13  bonus                       181560 non-null  float64
#  14  bps                         181560 non-null  float64
#  15  clean_sheets                181560 non-null  float64
#  16  goals_conceded              181560 non-null  float64
#  17  was_home                    181560 non-null  object
#  18  expected_assists            91985 non-null   float64
#  19  expected_goal_involvements  91985 non-null   float64
#  20  expected_goals              91985 non-null   float64
#  21  expected_goals_conceded     91985 non-null   float64
#  22  starts                      91985 non-null   float64
#  23  cbi                         32224 non-null   float64
#  24  defensive_contribution      11090 non-null   float64
#  25  recoveries                  32224 non-null   float64
#  26  tackles                     32224 non-null   float64
#  27  saves                       181560 non-null  float64
#  28  team_name                   199312 non-null  object
#  29  opp_team_name               199312 non-null  object
# dtypes: float64(25), object(5)
# memory usage: 45.6+ MB
# None

# %%
# Run SELECT and get results
view = db_creator.run_sql("""SELECT *
                        FROM playergw
                        WHERE event = 1
                        AND season = 20252026
                        AND team_name = 'Arsenal'
                        -- AND position = 'FWD'
                        AND total_points NOTNULL
                        ORDER BY total_points DESC
                          """)
view.head()
# Out:
#        player_name_id  element  value      season  event  fixture  \
# 0  Riccardo Calafiori      7.0   55.0  20252026.0    1.0      9.0
# 1   David Raya Martín      1.0   55.0  20252026.0    1.0      9.0
# 2      William Saliba      6.0   60.0  20252026.0    1.0      9.0
# 3         Declan Rice     21.0   65.0  20252026.0    1.0      9.0
# 4      Benjamin White     11.0   55.0  20252026.0    1.0      9.0
#
#    total_points  minutes  goals_scored  assists  ...  expected_goals  \
# 0          13.0     71.0           1.0      0.0  ...            0.91
# 1          10.0     90.0           0.0      0.0  ...            0.00
# 2           9.0     90.0           0.0      0.0  ...            0.00
# 3           6.0     82.0           0.0      1.0  ...            0.13
# 4           6.0     70.0           0.0      0.0  ...            0.01
#
#    expected_goals_conceded starts   cbi  defensive_contribution  recoveries  \
# 0                     0.87    1.0   3.0                     4.0         5.0
# 1                     1.52    1.0   1.0                     0.0        13.0
# 2                     1.52    1.0  10.0                    14.0         3.0
# 3                     1.04    1.0   1.0                     4.0         3.0
# 4                     0.87    1.0   6.0                     8.0         4.0
#
#    tackles saves  team_name  opp_team_name
# 0      1.0   0.0    Arsenal        Man Utd
# 1      0.0   7.0    Arsenal        Man Utd
# 2      4.0   0.0    Arsenal        Man Utd
# 3      0.0   0.0    Arsenal        Man Utd
# 4      2.0   0.0    Arsenal        Man Utd
#
# [5 rows x 30 columns]

# %%
view.columns.to_list
# Out:
# <bound method IndexOpsMixin.tolist of Index(['player_name_id', 'element', 'value', 'season', 'event', 'fixture',
#        'total_points', 'minutes', 'goals_scored', 'assists', 'team_elo',
#        'opp_team_elo', 'position', 'bonus', 'bps', 'clean_sheets',
#        'goals_conceded', 'was_home', 'expected_assists',
#        'expected_goal_involvements', 'expected_goals',
#        'expected_goals_conceded', 'starts', 'cbi', 'defensive_contribution',
#        'recoveries', 'tackles', 'saves', 'team_name', 'opp_team_name'],
#       dtype='object')>

# %%
fix.columns.to_list()
# Out:
# ['fixture_code',
#  'deadline_time',
#  'deadline_time_formatted',
#  'event',
#  'event_day',
#  'finished',
#  'finished_provisional',
#  'fixture_id',
#  'fixture_kickoff_time',
#  'fixture_kickoff_time_formatted',
#  'fixture_minutes',
#  'provisional_start_time',
#  'fixture_started',
#  'fixture_stats',
#  'team_a',
#  'team_a_difficulty',
#  'fixture_team_a_score',
#  'team_h',
#  'team_h_difficulty',
#  'fixture_team_h_score',
#  'fixture_season',
#  'away_team_name',
#  'home_team_name',
#  'home_team_elo',
#  'away_team_elo',
#  'pulse_id']

# %%
#percentage of fixtures finished by gameweek in 25/26 season
filtered =fix['fixture_season']==20252026 
tbl = fix[filtered].pivot_table(index='event',values='fixture_code' ,columns='finished',aggfunc='count')
out = tbl.div(tbl.sum(axis=1), axis=0)
out#[out[('finished','True')]>0]
# Out:
# finished  False  True
# event
# 1           NaN    1.0
# 2           NaN    1.0
# 3           NaN    1.0
# 4           NaN    1.0
# 5           NaN    1.0
# 6           NaN    1.0
# 7           NaN    1.0
# 8           NaN    1.0
# 9           NaN    1.0
# 10          NaN    1.0
# 11          NaN    1.0
# 12          NaN    1.0
# 13          NaN    1.0
# 14          NaN    1.0
# 15          0.3    0.7
# 16          1.0    NaN
# 17          1.0    NaN
# 18          1.0    NaN
# 19          1.0    NaN
# 20          1.0    NaN
# 21          1.0    NaN
# 22          1.0    NaN
# 23          1.0    NaN
# 24          1.0    NaN
# 25          1.0    NaN
# 26          1.0    NaN
# 27          1.0    NaN
# 28          1.0    NaN
# 29          1.0    NaN
# 30          1.0    NaN
# 31          1.0    NaN
# 32          1.0    NaN
# 33          1.0    NaN
# 34          1.0    NaN
# 35          1.0    NaN
# 36          1.0    NaN
# 37          1.0    NaN
# 38          1.0    NaN

# %%
# Max event where True is exactly 1.0
max_event_complete = out[out[True] == 1.0].index.max()

# Max event where True is greater than 0
max_event_started = out[out[True] > 0].index.max()

print(f"Max event where all fixtures finished (True = 1.0): {max_event_complete}")
print(f"Max event where some fixtures finished (True > 0): {max_event_started}")
# Out:
# Max event where all fixtures finished (True = 1.0): 14
# Max event where some fixtures finished (True > 0): 15

# %%
# df_rest_of_current_season.to_csv('data/FPL_Data_GWs_2018to25_vaastav.csv',index=False)
# fix.to_csv('data/FPL_Data_Fixtures_2018to25_vaastav.csv',index=False)

# %%
finish=time.perf_counter()
print(f'Finished in {round(((finish-start)/60),2)} minute(s)')
# Finished in 4.63 minute(s)
# Out:
# Finished in 1.93 minute(s)
